# %%
import torch
import cv2
import os
import pandas as pd
import numpy as np

# %%
def save_file_names():
    folder_path = os.path.abspath('/Users/cerenmorey/Desktop/BeCode/becode_projects/B&D/becode-signature-object-detection/test')
    all_files = os.listdir(folder_path)
    file_id = []
    for file in all_files:
        test_file_name = file[:-4]
        file_id.append(test_file_name)
    return file_id

# %%
file_id = save_file_names()
len(file_id)
# Out:
# 251

# %%
test_images = []
for i, name in enumerate(file_id):

    folder_path = os.path.abspath('/Users/cerenmorey/Desktop/BeCode/becode_projects/B&D/becode-signature-object-detection/test')
    file_path = os.path.join(folder_path, name+'.tif')
    img = cv2.imread(file_path, 0)
    test_images.append(img)

# %%
len(test_images)
# Out:
# 251

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom',  path='/Users/cerenmorey/Downloads/best (1).pt')
# Out:
# Using cache found in /Users/cerenmorey/.cache/torch/hub/ultralytics_yolov5_master
# requirements: seaborn>=0.11.0 not found and is required by YOLOv5, attempting auto-update...
# YOLOv5 🚀 caac981 torch 1.10.0 CPU
#
# Fusing layers...
# ...
#
# requirements: 1 package updated per /Users/cerenmorey/.cache/torch/hub/ultralytics_yolov5_master/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
# /Users/cerenmorey/opt/anaconda3/lib/python3.8/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
all_data = pd.DataFrame()

# %%
for i in range(len(test_images)):

    results = model(test_images[i])

    if len(results.pandas().xyxy[0]) > 0:
        temp_all_data = pd.DataFrame()
        temp_all_data = results.pandas().xyxy[0]
        temp_all_data['Id'] = file_id[i]
    #     temp_all_data['Id'] = file_id[i]
        all_data = all_data.append(temp_all_data, ignore_index=True)
    else:
        empty_data = pd.DataFrame([[0,0,0,0,0,100]],columns = ['xmin', 'ymin', 'xmax', 'ymax', 'confidence', 'class'])
        empty_data['Id'] = file_id[i]
        all_data = all_data.append(empty_data, ignore_index=True)
# Out:
# /Users/cerenmorey/opt/anaconda3/lib/python3.8/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# /Users/cerenmorey/opt/anaconda3/lib/python3.8/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# /Users/cerenmorey/opt/anaconda3/lib/python3.8/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# /Users/cerenmorey/opt/anaconda3/lib/python3.8/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
# ...

# %%
all_data
# Out:
#             xmin         ymin         xmax         ymax  confidence  class  \
# 0    1365.647095  1924.811279  1915.952515  2064.401123    0.876597      0
# 1     806.867981  1140.368896  1203.893311  1254.239502    0.863035      0
# 2       0.000000     0.000000     0.000000     0.000000    0.000000    100
# 3     807.058716  2350.531982  1696.620605  2704.097168    0.914436      0
# 4     726.902405  1729.268921  1215.453979  1881.296631    0.889637      0
# ..           ...          ...          ...          ...         ...    ...
# 308   552.466248   429.889465   851.386353   565.740173    0.901303      0
# 309   449.980438   651.168335   838.813354   749.266113    0.913648      0
# 310     0.000000    11.970432   251.219849    63.227615    0.316667      0
# 311   955.096436  2381.528320  1522.573975  2544.305420    0.889381      0
# 312  1276.544434  2039.698608  1903.321045  2226.505127    0.835827      0
#
#           name                                  Id
# ...

# %%
new_all_data = all_data.drop(['class','name'], axis = 1)

# %%
new_all_data = new_all_data.rename({"class":"Expected"}, axis = 1)

# %%
new_all_data = new_all_data.iloc[:, [5,0,1,2,3,4]]

# %%
new_all_data
# Out:
#                                      Id         xmin         ymin  \
# 0    dc703955d59f63982f81892900824cc4_1  1365.647095  1924.811279
# 1      083333af6122d35b285b062d52144332   806.867981  1140.368896
# 2    f6690637ad8d45c5a712cb3afb86b54c_3     0.000000     0.000000
# 3      1694540ff9371090fed21cf56ac9dba3   807.058716  2350.531982
# 4      43e00eab8fa5985f64dc91995dd33bfe   726.902405  1729.268921
# ..                                  ...          ...          ...
# 306    44212463201dbdfe0443f6ea8f229189   445.153656   939.856323
# 308  f12b9a1d92be06ce9357ae9a12a66e52_2   552.466248   429.889465
# 309    29ecd87fe6f74f21759b8776c79f8614   449.980438   651.168335
# 311    fd40cbeac18b5764fbd2f8d1d52e5640   955.096436  2381.528320
# 312    7921d3c75456cfe74d8d0a9d122d15b8  1276.544434  2039.698608
#
#             xmax         ymax  confidence
# 0    1915.952515  2064.401123    0.876597
# 1    1203.893311  1254.239502    0.863035
# 2       0.000000     0.000000    0.000000
# ...

# %%
new_all_data['Expected'] = new_all_data['Expected'].replace([100,0], [0,1])

# %%
new_all_data = new_all_data.drop_duplicates(subset=['Id'])

# %%
new_all_data.to_csv("bounding_box_test_dataset.csv", index = False)

# %%
kaggle = kaggle_set = all_data.drop(['xmin', 'ymin', 'xmax', 'ymax', 'confidence', 'name'], axis = 1)

# %%
kaggle = kaggle.rename({"class":"Expected"}, axis = 1)

# %%
kaggle
# Out:
#      Expected                                  Id
# 0           0  dc703955d59f63982f81892900824cc4_1
# 1           0    083333af6122d35b285b062d52144332
# 2         100  f6690637ad8d45c5a712cb3afb86b54c_3
# 3           0    1694540ff9371090fed21cf56ac9dba3
# 4           0    43e00eab8fa5985f64dc91995dd33bfe
# ..        ...                                 ...
# 308         0  f12b9a1d92be06ce9357ae9a12a66e52_2
# 309         0    29ecd87fe6f74f21759b8776c79f8614
# 310         0    29ecd87fe6f74f21759b8776c79f8614
# 311         0    fd40cbeac18b5764fbd2f8d1d52e5640
# 312         0    7921d3c75456cfe74d8d0a9d122d15b8
#
# [313 rows x 2 columns]

# %%
kaggle_classification_results['Expected'] = kaggle_classification_results['Expected'].replace([100], 1)

# %%
kaggle_classification_results['Expected'] = kaggle_classification_results['Expected'].replace([1], 0)
# Out:
# <ipython-input-74-34adac626e28>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kaggle_classification_results['Expected'] = kaggle_classification_results['Expected'].replace([1], 0)

# %%
kaggle =kaggle.iloc[:, [1,0]]

# %%
kaggle['Expected'] = kaggle['Expected'].replace([100,0], [0,1])
# Out:
# <ipython-input-98-7f1f2aac6346>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kaggle['Expected'] = kaggle['Expected'].replace([100,0], [0,1])

# %%
kaggle= kaggle.drop_duplicates(subset=['Id'])

# %%
kaggle.to_csv("signature_classification.csv", index = False)
